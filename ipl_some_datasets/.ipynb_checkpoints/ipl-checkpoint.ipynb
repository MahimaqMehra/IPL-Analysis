# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px

# %%
match_df=pd.read_csv('matches.csv')
ball_df=pd.read_csv('deliveries.csv')

# %%
match_df.head()
# Out:
#    season                 team1                        team2        date  \
# 0    2023   Chennai Super Kings               Gujarat Titans  2023/03/31
# 1    2023          Punjab Kings        Kolkata Knight Riders  2023/04/01
# 2    2023  Lucknow Super Giants               Delhi Capitals  2023/04/01
# 3    2023      Rajasthan Royals          Sunrisers Hyderabad  2023/04/02
# 4    2023        Mumbai Indians  Royal Challengers Bangalore  2023/04/02
#
#    match_number                                              venue  \
# 0             1                              Narendra Modi Stadium
# 1             2       Punjab Cricket Association IS Bindra Stadium
# 2             3  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 3             4                 Rajiv Gandhi International Stadium
# 4             5                              M Chinnaswamy Stadium
#
#          city                  toss_winner toss_decision player_of_match  \
# ...

# %%
ball_df.head()
# Out:
#    match_id  season  start_date                             venue  innings  \
# 0   1359475    2023  2023-03-31  Narendra Modi Stadium, Ahmedabad        1
# 1   1359475    2023  2023-03-31  Narendra Modi Stadium, Ahmedabad        1
# 2   1359475    2023  2023-03-31  Narendra Modi Stadium, Ahmedabad        1
# 3   1359475    2023  2023-03-31  Narendra Modi Stadium, Ahmedabad        1
# 4   1359475    2023  2023-03-31  Narendra Modi Stadium, Ahmedabad        1
#
#    ball         batting_team    bowling_team     striker non_striker  ...  \
# 0   0.1  Chennai Super Kings  Gujarat Titans   DP Conway  RD Gaikwad  ...
# 1   0.2  Chennai Super Kings  Gujarat Titans   DP Conway  RD Gaikwad  ...
# 2   0.3  Chennai Super Kings  Gujarat Titans  RD Gaikwad   DP Conway  ...
# 3   0.4  Chennai Super Kings  Gujarat Titans  RD Gaikwad   DP Conway  ...
# 4   0.5  Chennai Super Kings  Gujarat Titans   DP Conway  RD Gaikwad  ...
#
#   extras  wides  noballs  byes  legbyes  penalty  wicket_type  \
# ...

# %%
match_df.isna().sum()
# Out:
# season              0
# team1               0
# team2               0
# date                0
# match_number        0
# venue               0
# city                0
# toss_winner         0
# toss_decision       0
# player_of_match     1
# umpire1             0
# umpire2             0
# reserve_umpire      0
# match_referee       0
# winner              0
# winner_runs        34
# winner_wickets     41
# match_type          0
# dtype: int64

# %%
ball_df.isna().sum()
# Out:
# match_id                      0
# season                        0
# start_date                    0
# venue                         0
# innings                       0
# ball                          0
# batting_team                  0
# bowling_team                  0
# striker                       0
# non_striker                   0
# bowler                        0
# runs_off_bat                  0
# extras                        0
# wides                     17237
# noballs                   17763
# byes                      17818
# legbyes                   17616
# penalty                   17863
# wicket_type               16947
# player_dismissed          16947
# other_wicket_type         17863
# other_player_dismissed    17863
# dtype: int64

# %%
match_df.team1.unique()
# Out:
# array(['Chennai Super Kings', 'Punjab Kings', 'Lucknow Super Giants',
#        'Rajasthan Royals', 'Mumbai Indians', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Sunrisers Hyderabad', 'Gujarat Titans',
#        'Royal Challengers Bangalore'], dtype=object)

# %%
match_df['match_id']=ball_df['match_id'].unique()

# %%
match_df.head()
# Out:
#    season                 team1                        team2        date  \
# 0    2023   Chennai Super Kings               Gujarat Titans  2023/03/31
# 1    2023          Punjab Kings        Kolkata Knight Riders  2023/04/01
# 2    2023  Lucknow Super Giants               Delhi Capitals  2023/04/01
# 3    2023      Rajasthan Royals          Sunrisers Hyderabad  2023/04/02
# 4    2023        Mumbai Indians  Royal Challengers Bangalore  2023/04/02
#
#    match_number                                              venue  \
# 0             1                              Narendra Modi Stadium
# 1             2       Punjab Cricket Association IS Bindra Stadium
# 2             3  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 3             4                 Rajiv Gandhi International Stadium
# 4             5                              M Chinnaswamy Stadium
#
#          city                  toss_winner toss_decision player_of_match  \
# ...

# %%
short_names={'Chennai Super Kings':'CSK', 'Punjab Kings':'PBKS', 'Lucknow Super Giants':'LSG',
       'Rajasthan Royals':'RR', 'Mumbai Indians':'MI', 'Delhi Capitals':'DC',
       'Kolkata Knight Riders':'KKR', 'Sunrisers Hyderabad':'SRH', 'Gujarat Titans':'GT',
       'Royal Challengers Bangalore':'RCB'}

# %%
figure=sns.countplot(match_df.winner)
plt.title("Number of matches won in IPL")
plt.figure(figsize=(2,2))

# %%
figure=sns.countplot(match_df.player_of_match)
plt.title("Number of matches won in IPL")
plt.figure(figsize=(2,2))

# %%
import plotly.io as pio
pio.renderers.default = 'iframe' # or 'colab' or 'iframe' or 'iframe_connected' or 'sphinx_gallery'
figure= px.bar(match_df,x=match_df["player_of_match"] , title="most player of match") 
figure.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_33.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
