# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
#since without it plotly doesnt work
import plotly.io as pio
pio.renderers.default = 'iframe' # or 'colab' or 'iframe' or 'iframe_connected' or 'sphinx_gallery'

# geeks for geeks to refer to notes 

#import matplotlib.pyplot as plt
#import seaborn as sns
#import plotly.express as px
#import plotly.graph_objects as go
#------------------------
# 1--> for count graph-on 1 value
# 2--> for bar graph-on 2 value
#---------------------------
#1-->f=plt.bar(df.bowl) basic function so cant count ---line graph
#plt.title("hello")

#2-->f= plt.bar(df.bowl,df.bat) 
#3-->plt.pie(df.bat, labels = df.bowl)
#4-->plt.plot(df.bowl,df.bat) 
#5->plt.hist(df.bowl,bins=5)
#-------------------
#1-->f=sns.countplot(x=df.bowl) orirntation gets wrong -------bar graph,pie chart --just gives more designing features 
#plt.title("hello")

#2-->f= sns.barplot(x=df.bowl , y=df.bat)
#3-->plt.pie(df.bat, labels=df.bowl, colors=palette_color, autopct='%.0f%%')
#4-->f= sns.scatterplot(x=df.bowl , y=df.bat)        hue=runs-----to give different colour
#5-->f=sns.pivot(month,year,passengers)  -----to draw like row columns to fill values
#sns.heatmap(f)      ---------------to draw like row columns to fill colour

#-------------------
#1-->f=px.bar(df,x=df["bowl"],title="hello") advanced , interactive---if lot of bar graph 
#f.show()

#2-->f= px.bar(df,x=df["bowl"] ,y=df["bat"])      color=df["bowl"]-----to give different colour
#f.show()

#3-->method--1-- when number 
#fig = px.pie(values = [20, 50, 37, 18],
 #            names = ['G1', 'G2', 'G3', 'G4'])


# Equivalent to:
# import pandas as pd
# df = pd.DataFrame({'values': [20, 50, 37, 18],
#                    'groups' = ['G1', 'G2', 'G3', 'G4']})
# fig = px.pie(df, values = 'values', names = 'groups')

#fig.show()
----------------------------------------------------

# %%
data = pd.read_csv('ipl2022.csv')

# %%
data
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# ..       ...            ...                                           ...
# 69        70    May 22,2022                      Wankhede Stadium, Mumbai
# 70        71    May 24,2022                         Eden Gardens, Kolkata
# 71        72    May 25,2022                         Eden Gardens, Kolkata
# 72        73    May 27,2022              Narendra Modi Stadium, Ahmedabad
# 73        74    May 29,2022              Narendra Modi Stadium, Ahmedabad
#
#         team1      team2    stage toss_winner toss_decision  first_ings_score  \
# ...

# %%
figure=sns.countplot(x=data.match_winner) #by default considering y axis
plt.title("Number of matches won in IPL")
plt.figure(figsize=(50,10)) #width height

# %%
figure=sns.countplot(x=data.match_winner) #by default considering y axis
plt.title("Number of matches won in IPL")
plt.figure(figsize=(50,10)) #width height
sns.set_style("darkgrid")

# %%
import matplotlib.pyplot as plt 
import seaborn 
  
# declaring data 
da = [44, 45, 40, 41, 39] 
keys = ['Class 1', 'Class 2', 'CLass 3', 'Class 4', 'Class 5'] 
  
# declaring exploding pie 
explode = [0, 0.1, 0, 0, 0] 
# define Seaborn color palette to use 
palette_color = seaborn.color_palette('dark') 
  
# plotting data on chart 
plt.pie(da, labels=keys, colors=palette_color, 
        explode=explode, autopct='%.0f%%') 
  
# displaying chart 
plt.show()

# %%
figure=sns.countplot(x=data.best_bowling) #by default considering y axis
plt.title("Number of matches won in IPL")
plt.figure(figsize=(50,1)) #width height
sns.set_style("darkgrid")

# %%
import plotly.io as pio
pio.renderers.default = 'iframe' # or 'colab' or 'iframe' or 'iframe_connected' or 'sphinx_gallery'
figure= px.bar(data,x=data["best_bowling"],title="best bowling") 
figure.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_125.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
import plotly.io as pio
pio.renderers.default = 'iframe' # or 'colab' or 'iframe' or 'iframe_connected' or 'sphinx_gallery'
figure= px.bar(data,x=data["player_of_the_match"] , title="most player of match") 
figure.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_124.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
top scorer IPL 2022

# %%
import plotly.io as pio
pio.renderers.default = 'iframe' # or 'colab' or 'iframe' or 'iframe_connected' or 'sphinx_gallery'
figure= px.bar(data,x=data["top_scorer"] ,y=data["highscore"], color=data["highscore"],title="top scorer IPL 2022") 
figure.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_131.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
